# %%
import sys
sys.path.append("../src")

import numpy as np

from melfa_kinematics.melfa_rv2aj import forward_kinematics

# %%
q = [0, 0, 0]

T = forward_kinematics(q)

print(T)

# %%
q = [
    np.pi / 4,
    np.pi / 6,
    -np.pi / 8
]

T = forward_kinematics(q)

print(T)
